# %%
# Cell 1: Imports
import sys
sys.path.append('..')

import torch
import numpy as np
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import DataLoader

from src.models import MultimodalFusionModel
from src.preprocessing import ADNIDataset, get_train_transforms
from src.training import train_epoch, validate, get_balanced_sampler, get_class_weights

# Cell 2: Load preprocessed data
# ... (load your dataset_records)

# Cell 3: Cross-validation loop
# ... (your training code)
