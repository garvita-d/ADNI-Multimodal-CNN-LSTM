# %%
# Cell 1: Imports
import sys
sys.path.append('..')

from src.evaluation import (
    compute_gradcam_3d,
    visualize_gradcam_3d,
    visualize_lstm_attention,
    compute_feature_importance,
    plot_feature_importance
)

# Cell 2: Load trained model
# ... (load best model)

# Cell 3: Grad-CAM visualization
# ... (XAI analysis)
